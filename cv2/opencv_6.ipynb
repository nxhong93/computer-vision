# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import sys

# %%
#reduce image
# Draw vertical seam on top of the image 
def overlay_vertical_seam(img, seam): 
    img_seam_overlay = np.copy(img)
 
    # Extract the list of points from the seam 
    x_coords, y_coords = np.transpose([(i,int(j)) for i,j in enumerate(seam)]) 
 
    # Draw a green line on the image using the list of points 
    img_seam_overlay[x_coords, y_coords] = (0,255,0) 
    return img_seam_overlay
 
# Compute the energy matrix from the input image 
def compute_energy_matrix(img): 
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
 
    # Compute X derivative of the image 
    sobel_x = cv2.Sobel(gray,cv2.CV_64F, 1, 0, ksize=3) 
 
    # Compute Y derivative of the image 
    sobel_y = cv2.Sobel(gray,cv2.CV_64F, 0, 1, ksize=3) 
 
    abs_sobel_x = cv2.convertScaleAbs(sobel_x) 
    abs_sobel_y = cv2.convertScaleAbs(sobel_y) 
 
    # Return weighted summation of the two images i.e. 0.5*X + 0.5*Y 
    return cv2.addWeighted(abs_sobel_x, 0.5, abs_sobel_y, 0.5, 0) 
 
# Find vertical seam in the input image 
def find_vertical_seam(img, energy): 
    rows, cols = img.shape[:2] 
 
    # Initialize the seam vector with 0 for each element 
    seam = np.zeros(img.shape[0]) 
 
    # Initialize distance and edge matrices 
    dist_to = np.zeros(img.shape[:2]) + float('inf')
    dist_to[0,:] = np.zeros(img.shape[1]) 
    edge_to = np.zeros(img.shape[:2]) 
 
    # Dynamic programming; iterate using double loop and compute the paths efficiently 
    for row in range(rows-1): 
        for col in range(cols): 
            if col != 0 and dist_to[row+1, col-1] > dist_to[row, col] + energy[row+1, col-1]: 
                dist_to[row+1, col-1] = dist_to[row, col] + energy[row+1, col-1]
                edge_to[row+1, col-1] = 1 
 
            if dist_to[row+1, col] > dist_to[row, col] + energy[row+1, col]: 
                dist_to[row+1, col] = dist_to[row, col] + energy[row+1, col] 
                edge_to[row+1, col] = 0 

            if col != cols-1 and dist_to[row+1, col+1] > dist_to[row, col] + energy[row+1, col+1]: 
                    dist_to[row+1, col+1] = dist_to[row, col] + energy[row+1, col+1] 
                    edge_to[row+1, col+1] = -1 
 
    # Retracing the path 
    # Returns the indices of the minimum values along X axis.
    seam[rows-1] = np.argmin(dist_to[rows-1, :]) 
    for i in (x for x in reversed(range(rows)) if x > 0): 
        seam[i-1] = seam[i] + edge_to[i, int(seam[i])] 
 
    return seam 
 
# Remove the input vertical seam from the image 
def remove_vertical_seam(img, seam): 
    rows, cols = img.shape[:2] 
 
    # To delete a point, move every point after it one step towards the left 
    for row in range(rows): 
        for col in range(int(seam[row]), cols-1): 
            img[row, col] = img[row, col+1] 
 
    # Discard the last column to create the final output image 
    img = img[:, 0:cols-1] 
    return img 
 
if __name__=='__main__': 
    # Make sure the size of the input image is reasonable. 
    # Large images take a lot of time to be processed. 
    # Recommended size is 640x480. 
    img_input = cv2.imread('./images/ducks.jpg')
 
    # Use a small number to get started. Once you get an 
    # idea of the processing time, you can use a bigger number. 
    # To get started, you can set it to 20. 
    num_seams = 20 
 
    img = np.copy(img_input) 
    img_overlay_seam = np.copy(img_input) 
    energy = compute_energy_matrix(img) 
 
    for i in range(num_seams): 
        seam = find_vertical_seam(img, energy) 
        img_overlay_seam = overlay_vertical_seam(img_overlay_seam, seam)
        img = remove_vertical_seam(img, seam) 
        energy = compute_energy_matrix(img) 
        print('Number of seams removed = ', i+1) 
 
    cv2.imshow('Input', img_input) 
    cv2.imshow('Seams', img_overlay_seam) 
    cv2.imshow('Output', img) 
    cv2.waitKey()
# Out:
# Number of seams removed =  1
# Number of seams removed =  2
# Number of seams removed =  3
# Number of seams removed =  4
# Number of seams removed =  5
# Number of seams removed =  6
# Number of seams removed =  7
# Number of seams removed =  8
# Number of seams removed =  9
# Number of seams removed =  10
# Number of seams removed =  11
# Number of seams removed =  12
# Number of seams removed =  13
# Number of seams removed =  14
# Number of seams removed =  15
# Number of seams removed =  16
# Number of seams removed =  17
# Number of seams removed =  18
# Number of seams removed =  19
# Number of seams removed =  20

# %%
#expand image
# Draw vertical seam on top of the image 
def overlay_vertical_seam(img, seam): 
    img_seam_overlay = np.copy(img)
 
    # Extract the list of points from the seam 
    x_coords, y_coords = np.transpose([(i,int(j)) for i,j in enumerate(seam)]) 
 
    # Draw a green line on the image using the list of points 
    img_seam_overlay[x_coords, y_coords] = (0,255,0) 
    return img_seam_overlay

# Compute the energy matrix from the input image 
def compute_energy_matrix(img): 
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
    sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3) 
    sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3) 
    abs_sobel_x = cv2.convertScaleAbs(sobel_x) 
    abs_sobel_y = cv2.convertScaleAbs(sobel_y) 
    return cv2.addWeighted(abs_sobel_x, 0.5, abs_sobel_y, 0.5, 0) 
 
# Find the vertical seam 
def find_vertical_seam(img, energy): 
    rows, cols = img.shape[:2] 
 
    # Initialize the seam vector with 0 for each element 
    seam = np.zeros(img.shape[0]) 
 
    # Initialize distance and edge matrices 
    dist_to = np.zeros(img.shape[:2]) + float('inf') 
    dist_to[0,:] = np.zeros(img.shape[1]) 
    edge_to = np.zeros(img.shape[:2]) 
 
    # Dynamic programming; iterate using double loop and compute 
    #the paths efficiently 
    for row in range(rows-1): 
        for col in range(cols): 
            if col != 0 and \
            dist_to[row+1, col-1] > dist_to[row, col] + energy[row+1, col-1]: 
                dist_to[row+1, col-1] = dist_to[row, col] + energy[row+1, col-1] 
                edge_to[row+1, col-1] = 1 
 
            if dist_to[row+1, col] > dist_to[row, col] + energy[row+1, col]: 
                dist_to[row+1, col] = dist_to[row, col] + energy[row+1, col] 
                edge_to[row+1, col] = 0 
 
            if col != cols-1: 
                if dist_to[row+1, col+1] > dist_to[row, col] + energy[row+1, col+1]: 
                    dist_to[row+1, col+1] = dist_to[row, col] + energy[row+1, col+1] 
                    edge_to[row+1, col+1] = -1
 
    # Retracing the path 
    seam[rows-1] = np.argmin(dist_to[rows-1, :]) 
    for i in (x for x in reversed(range(rows)) if x > 0): 
        seam[i-1] = seam[i] + edge_to[i, int(seam[i])] 
 
    return seam 
 
# Add a vertical seam to the image 
def add_vertical_seam(img, seam, num_iter): 
    seam = seam + num_iter 
    rows, cols = img.shape[:2] 
    zero_col_mat = np.zeros((rows,1,3), dtype=np.uint8) 
    img_extended = np.hstack((img, zero_col_mat)) 
 
    for row in range(rows): 
        for col in range(cols, int(seam[row]), -1): 
            img_extended[row, col] = img[row, col-1] 
 
        # To insert a value between two columns, take the average 
        # value of the neighbors. It looks smooth this way and we 
        # can avoid unwanted artifacts. 
        for i in range(3): 
            v1 = img_extended[row, int(seam[row])-1, i] 
            v2 = img_extended[row, int(seam[row])+1, i] 
            img_extended[row, int(seam[row]), i] = (int(v1)+int(v2))/2 
 
    return img_extended 
 
# Remove vertical seam from the image 
def remove_vertical_seam(img, seam): 
    rows, cols = img.shape[:2] 
    for row in range(rows): 
        for col in range(int(seam[row]), cols-1): 
            img[row, col] = img[row, col+1] 
 
    img = img[:, 0:cols-1] 
    return img 
 
if __name__=='__main__': 
    img_input = cv2.imread('./images/ducks.jpg') 
    num_seams = 20
    
    img = np.copy(img_input) 
    img_output = np.copy(img_input) 
    img_overlay_seam = np.copy(img_input) 
    energy = compute_energy_matrix(img) 
 
    for i in range(num_seams): 
        seam = find_vertical_seam(img, energy) 
        img_overlay_seam = overlay_vertical_seam(img_overlay_seam, seam)
        img = remove_vertical_seam(img, seam)
        img_output = add_vertical_seam(img_output, seam, i) 
        energy = compute_energy_matrix(img) 
        print('Number of seams added =', i+1)
 
    cv2.imshow('Input', img_input) 
    cv2.imshow('Seams', img_overlay_seam)
    cv2.imshow('Output', img_output) 
    cv2.waitKey()
# Out:
# Number of seams added = 1
# Number of seams added = 2
# Number of seams added = 3
# Number of seams added = 4
# Number of seams added = 5
# Number of seams added = 6
# Number of seams added = 7
# Number of seams added = 8
# Number of seams added = 9
# Number of seams added = 10
# Number of seams added = 11
# Number of seams added = 12
# Number of seams added = 13
# Number of seams added = 14
# Number of seams added = 15
# Number of seams added = 16
# Number of seams added = 17
# Number of seams added = 18
# Number of seams added = 19
# Number of seams added = 20

# %%
#remove object
# Draw rectangle on top of the input image 
def draw_rectangle(event, x, y, flags, params): 
    global x_init, y_init, drawing, top_left_pt, bottom_right_pt, img_orig 
 
    # Detecting a mouse click 
    if event == cv2.EVENT_LBUTTONDOWN: 
        drawing = True 
        x_init, y_init = x, y 
 
    # Detecting mouse movement 
    elif event == cv2.EVENT_MOUSEMOVE: 
        if drawing: 
            top_left_pt, bottom_right_pt = (x_init,y_init), (x,y) 
            img[y_init:y, x_init:x] = 255 - img_orig[y_init:y, x_init:x] 
            cv2.rectangle(img, top_left_pt, bottom_right_pt, (0,255,0), 2) 
 
    # Detecting the mouse button up event 
    elif event == cv2.EVENT_LBUTTONUP: 
        drawing = False 
        top_left_pt, bottom_right_pt = (x_init,y_init), (x,y) 
 
        # Create the "negative" film effect for the selected 
         # region 
        img[y_init:y, x_init:x] = 255 - img[y_init:y, x_init:x] 
 
        # Draw rectangle around the selected region 
        cv2.rectangle(img, top_left_pt, bottom_right_pt, (0,255,0), 2) 
        rect_final = (x_init, y_init, x-x_init, y-y_init) 
 
        # Remove the object in the selected region 
        remove_object(img_orig, rect_final) 
 
# Computing the energy matrix using modified algorithm 
def compute_energy_matrix_modified(img, rect_roi): 
    # Compute weighted summation i.e. 0.5*X + 0.5*Y 
    energy_matrix = compute_energy_matrix(img)
    x,y,w,h = rect_roi 
 
    # We want the seams to pass through this region, so make sure the energy values in this region are set to 0 
    energy_matrix[y:y+h, x:x+w] = 0 
 
    return energy_matrix 
 
# Compute energy matrix 
def compute_energy_matrix(img): 
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
 
    # Compute X derivative 
    sobel_x = cv2.Sobel(gray, cv2.CV_64F, 1, 0, ksize=3) 
 
    # Compute Y derivative 
    sobel_y = cv2.Sobel(gray, cv2.CV_64F, 0, 1, ksize=3) 
    abs_sobel_x = cv2.convertScaleAbs(sobel_x) 
    abs_sobel_y = cv2.convertScaleAbs(sobel_y) 
 
    # Return weighted summation i.e. 0.5*X + 0.5*Y 
    return cv2.addWeighted(abs_sobel_x, 0.5, abs_sobel_y, 0.5, 0) 
 
# Find the vertical seam 
def find_vertical_seam(img, energy): 
    rows, cols = img.shape[:2] 
 
    # Initialize the seam vector 
    seam = np.zeros(img.shape[0]) 
 
    # Initialize the distance and edge matrices 
    dist_to = np.zeros(img.shape[:2]) + float('inf')
    dist_to[0,:] = np.zeros(img.shape[1]) 
    edge_to = np.zeros(img.shape[:2]) 
 
    # Dynamic programming; using double loop to compute the paths 
    for row in range(rows-1): 
        for col in range(cols): 
            if col != 0 and dist_to[row+1, col-1] > dist_to[row, col] + energy[row+1, col-1]: 
                dist_to[row+1, col-1] = dist_to[row, col] + energy[row+1, col-1] 
                edge_to[row+1, col-1] = 1 
 
            if dist_to[row+1, col] > dist_to[row, col] + energy[row+1, col]: 
                dist_to[row+1, col] = dist_to[row, col] + energy[row+1, col] 
                edge_to[row+1, col] = 0
 
            if col != cols-1 and dist_to[row+1, col+1] > dist_to[row, col] + energy[row+1, col+1]: 
                dist_to[row+1, col+1] = dist_to[row, col] + energy[row+1, col+1] 
                edge_to[row+1, col+1] = -1 
 
    # Retracing the path 
    seam[rows-1] = np.argmin(dist_to[rows-1, :]) 
    for i in (x for x in reversed(range(rows)) if x > 0): 
        seam[i-1] = seam[i] + edge_to[i, int(seam[i])] 
 
    return seam 
 
# Add vertical seam to the input image 
def add_vertical_seam(img, seam, num_iter): 
    seam = seam + num_iter 
    rows, cols = img.shape[:2] 
    zero_col_mat = np.zeros((rows,1,3), dtype=np.uint8) 
    img_extended = np.hstack((img, zero_col_mat)) 
 
    for row in range(rows): 
        for col in range(cols, int(seam[row]), -1): 
            img_extended[row, col] = img[row, col-1] 
 
        # To insert a value between two columns, take the average 
        # value of the neighbors. It looks smooth this way and we 
        # can avoid unwanted artifacts. 
        for i in range(3): 
            v1 = img_extended[row, int(seam[row])-1, i] 
            v2 = img_extended[row, int(seam[row])+1, i] 
            img_extended[row, int(seam[row]), i] = (int(v1)+int(v2))/2 
 
    return img_extended 
 
# Remove vertical seam 
def remove_vertical_seam(img, seam): 
    rows, cols = img.shape[:2] 
    for row in range(rows): 
        for col in range(int(seam[row]), cols-1): 
            img[row, col] = img[row, col+1] 
 
    img = img[:, 0:cols-1] 
    return img 
 
# Remove the object from the input region of interest 
def remove_object(img, rect_roi): 
    num_seams = rect_roi[2] + 10 
    energy = compute_energy_matrix_modified(img, rect_roi) 
 
    # Start a loop and rsemove one seam at a time 
    for i in range(num_seams): 
        # Find the vertical seam that can be removed 
        seam = find_vertical_seam(img, energy) 
 
        # Remove that vertical seam 
        img = remove_vertical_seam(img, seam) 
        x,y,w,h = rect_roi 
 
        # Compute energy matrix after removing the seam 
        energy = compute_energy_matrix_modified(img, (x,y,w-i,h)) 
        print('Number of seams removed =', i+1)
 
    img_output = np.copy(img) 
 
    # Fill up the region with surrounding values so that the size 
    # of the image remains unchanged 
    for i in range(num_seams): 
        seam = find_vertical_seam(img, energy) 
        img = remove_vertical_seam(img, seam) 
        img_output = add_vertical_seam(img_output, seam, i) 
        energy = compute_energy_matrix(img) 
        print('Number of seams added =', i+1) 
 
    cv2.imshow('Input', img_input) 
    cv2.imshow('Output', img_output) 
    cv2.waitKey() 
 
if __name__=='__main__': 
    img_input = cv2.imread('./images/beach.jpg')
    drawing = False 
    img = np.copy(img_input) 
    img_orig = np.copy(img_input) 
 
    cv2.namedWindow('Input') 
    cv2.setMouseCallback('Input', draw_rectangle)
    print('Draw a rectangle onto the object to be removed')
    while True:
        cv2.imshow('Input', img) 
        c = cv2.waitKey(10) 
        if c == 27: 
            break 
 
    cv2.destroyAllWindows()
# Out:
# Draw a rectangle onto the object to be removed
# Number of seams removed = 1
# Number of seams removed = 2
# Number of seams removed = 3
# Number of seams removed = 4
# Number of seams removed = 5
# Number of seams removed = 6
# Number of seams removed = 7
# Number of seams removed = 8
# Number of seams removed = 9
# Number of seams removed = 10
# Number of seams removed = 11
# Number of seams removed = 12
# Number of seams removed = 13
# Number of seams removed = 14
# Number of seams removed = 15
# Number of seams removed = 16
# Number of seams removed = 17
# Number of seams removed = 18
# Number of seams removed = 19
# Number of seams removed = 20
# Number of seams removed = 21
# Number of seams removed = 22
# Number of seams removed = 23
# Number of seams removed = 24
# Number of seams removed = 25
# Number of seams removed = 26
# Number of seams removed = 27
# Number of seams removed = 28
# Number of seams removed = 29
# Number of seams removed = 30
# Number of seams removed = 31
# Number of seams removed = 32
# Number of seams removed = 33
# Number of seams removed = 34
# Number of seams removed = 35
# Number of seams removed = 36
# Number of seams removed = 37
# Number of seams removed = 38
# Number of seams removed = 39
# Number of seams removed = 40
# Number of seams removed = 41
# Number of seams removed = 42
# Number of seams removed = 43
# Number of seams removed = 44
# Number of seams removed = 45
# Number of seams removed = 46
# Number of seams removed = 47
# Number of seams removed = 48
# Number of seams removed = 49
# Number of seams removed = 50
# Number of seams removed = 51
# Number of seams removed = 52
# Number of seams removed = 53
# Number of seams removed = 54
# Number of seams removed = 55
# Number of seams removed = 56
# Number of seams removed = 57
# Number of seams removed = 58
# Number of seams removed = 59
# Number of seams removed = 60
# Number of seams removed = 61
# Number of seams removed = 62
# Number of seams removed = 63
# Number of seams removed = 64
# Number of seams removed = 65
# Number of seams removed = 66
# Number of seams removed = 67
# Number of seams removed = 68
# Number of seams removed = 69
# Number of seams removed = 70
# Number of seams removed = 71
# Number of seams removed = 72
# Number of seams removed = 73
# Number of seams removed = 74
# Number of seams removed = 75
# Number of seams removed = 76
# Number of seams removed = 77
# Number of seams removed = 78
# Number of seams removed = 79
# Number of seams removed = 80
# Number of seams removed = 81
# Number of seams removed = 82
# Number of seams removed = 83
# Number of seams removed = 84
# Number of seams removed = 85
# Number of seams removed = 86
# Number of seams removed = 87
# Number of seams removed = 88
# Number of seams removed = 89
# Number of seams removed = 90
# Number of seams removed = 91
# Number of seams removed = 92
# Number of seams removed = 93
# Number of seams removed = 94
# Number of seams removed = 95
# Number of seams removed = 96
# Number of seams removed = 97
# Number of seams removed = 98
# Number of seams removed = 99
# Number of seams removed = 100
# Number of seams removed = 101
# Number of seams removed = 102
# Number of seams removed = 103
# Number of seams removed = 104
# Number of seams removed = 105
# Number of seams removed = 106
# Number of seams removed = 107
# Number of seams removed = 108
# Number of seams removed = 109
# Number of seams removed = 110
# Number of seams removed = 111
# Number of seams removed = 112
# Number of seams removed = 113
# Number of seams removed = 114
# Number of seams removed = 115
# Number of seams removed = 116
# Number of seams removed = 117
# Number of seams removed = 118
# Number of seams removed = 119
# Number of seams removed = 120
# Number of seams removed = 121
# Number of seams removed = 122
# Number of seams removed = 123
# Number of seams removed = 124
# Number of seams removed = 125
# Number of seams removed = 126
# Number of seams removed = 127
# Number of seams removed = 128
# Number of seams removed = 129
# Number of seams removed = 130
# Number of seams removed = 131
# Number of seams removed = 132
# Number of seams removed = 133
# Number of seams removed = 134
# Number of seams removed = 135
# Number of seams removed = 136
# Number of seams removed = 137
# Number of seams removed = 138
# Number of seams removed = 139
# Number of seams removed = 140
# Number of seams removed = 141
# Number of seams removed = 142
# Number of seams removed = 143
# Number of seams removed = 144
# Number of seams removed = 145
# Number of seams removed = 146
# Number of seams removed = 147
# Number of seams removed = 148
# Number of seams removed = 149
# Number of seams removed = 150
# Number of seams removed = 151
# Number of seams removed = 152
# Number of seams removed = 153
# Number of seams removed = 154
# Number of seams removed = 155
# Number of seams removed = 156
# Number of seams removed = 157
# Number of seams removed = 158
# Number of seams removed = 159
# Number of seams removed = 160
# Number of seams removed = 161
# Number of seams removed = 162
# Number of seams removed = 163
# Number of seams removed = 164
# Number of seams removed = 165
# Number of seams removed = 166
# Number of seams removed = 167
# Number of seams removed = 168
# Number of seams removed = 169
# Number of seams removed = 170
# Number of seams removed = 171
# Number of seams removed = 172
# Number of seams removed = 173
# Number of seams removed = 174
# Number of seams removed = 175
# Number of seams removed = 176
# Number of seams removed = 177
# Number of seams removed = 178
# Number of seams removed = 179
# Number of seams removed = 180
# Number of seams removed = 181
# Number of seams removed = 182
# Number of seams removed = 183
# Number of seams removed = 184
# Number of seams removed = 185
# Number of seams removed = 186
# Number of seams removed = 187
# Number of seams removed = 188
# Number of seams removed = 189
# Number of seams removed = 190
# Number of seams removed = 191
# Number of seams removed = 192
# Number of seams removed = 193
# Number of seams removed = 194
# Number of seams removed = 195
# Number of seams removed = 196
# Number of seams removed = 197
# Number of seams removed = 198
# Number of seams removed = 199
# Number of seams removed = 200
# Number of seams removed = 201
# Number of seams added = 1
# Number of seams added = 2
# Number of seams added = 3
# Number of seams added = 4
# Number of seams added = 5
# Number of seams added = 6
# Number of seams added = 7
# Number of seams added = 8
# Number of seams added = 9
# Number of seams added = 10
# Number of seams added = 11
# Number of seams added = 12
# Number of seams added = 13
# Number of seams added = 14
# Number of seams added = 15
# Number of seams added = 16
# Number of seams added = 17
# Number of seams added = 18
# Number of seams added = 19
# Number of seams added = 20
# Number of seams added = 21
# Number of seams added = 22
# Number of seams added = 23
# Number of seams added = 24
# Number of seams added = 25
# Number of seams added = 26
# Number of seams added = 27
# Number of seams added = 28
# Number of seams added = 29
# Number of seams added = 30
# Number of seams added = 31
# Number of seams added = 32
# Number of seams added = 33
# Number of seams added = 34
# Number of seams added = 35
# Number of seams added = 36
# Number of seams added = 37
# Number of seams added = 38
# Number of seams added = 39
# Number of seams added = 40
# Number of seams added = 41
# Number of seams added = 42
# Number of seams added = 43
# Number of seams added = 44
# Number of seams added = 45
# Number of seams added = 46
# Number of seams added = 47
# Number of seams added = 48
# Number of seams added = 49
# Number of seams added = 50
# Number of seams added = 51
# Number of seams added = 52
# Number of seams added = 53
# Number of seams added = 54
# Number of seams added = 55
# Number of seams added = 56
# Number of seams added = 57
# Number of seams added = 58
# Number of seams added = 59
# Number of seams added = 60
# Number of seams added = 61
# Number of seams added = 62
# Number of seams added = 63
# Number of seams added = 64
# Number of seams added = 65
# Number of seams added = 66
# Number of seams added = 67
# Number of seams added = 68
# Number of seams added = 69
# Number of seams added = 70
# Number of seams added = 71
# Number of seams added = 72
# Number of seams added = 73
# Number of seams added = 74
# Number of seams added = 75
# Number of seams added = 76
# Number of seams added = 77
# Number of seams added = 78
# Number of seams added = 79
# Number of seams added = 80
# Number of seams added = 81
# Number of seams added = 82
# Number of seams added = 83
# Number of seams added = 84
# Number of seams added = 85
# Number of seams added = 86
# Number of seams added = 87
# Number of seams added = 88
# Number of seams added = 89
# Number of seams added = 90
# Number of seams added = 91
# Number of seams added = 92
# Number of seams added = 93
# Number of seams added = 94
# Number of seams added = 95
# Number of seams added = 96
# Number of seams added = 97
# Number of seams added = 98
# Number of seams added = 99
# Number of seams added = 100
# Number of seams added = 101
# Number of seams added = 102
# Number of seams added = 103
# Number of seams added = 104
# Number of seams added = 105
# Number of seams added = 106
# Number of seams added = 107
# Number of seams added = 108
# Number of seams added = 109
# Number of seams added = 110
# Number of seams added = 111
# Number of seams added = 112
# Number of seams added = 113
# Number of seams added = 114
# Number of seams added = 115
# Number of seams added = 116
# Number of seams added = 117
# Number of seams added = 118
# Number of seams added = 119
# Number of seams added = 120
# Number of seams added = 121
# Number of seams added = 122
# Number of seams added = 123
# Number of seams added = 124
# Number of seams added = 125
# Number of seams added = 126
# Number of seams added = 127
# Number of seams added = 128
# Number of seams added = 129
# Number of seams added = 130
# Number of seams added = 131
# Number of seams added = 132
# Number of seams added = 133
# Number of seams added = 134
# Number of seams added = 135
# Number of seams added = 136
# Number of seams added = 137
# Number of seams added = 138
# Number of seams added = 139
# Number of seams added = 140
# Number of seams added = 141
# Number of seams added = 142
# Number of seams added = 143
# Number of seams added = 144
# Number of seams added = 145
# Number of seams added = 146
# Number of seams added = 147
# Number of seams added = 148
# Number of seams added = 149
# Number of seams added = 150
# Number of seams added = 151
# Number of seams added = 152
# Number of seams added = 153
# Number of seams added = 154
# Number of seams added = 155
# Number of seams added = 156
# Number of seams added = 157
# Number of seams added = 158
# Number of seams added = 159
# Number of seams added = 160
# Number of seams added = 161
# Number of seams added = 162
# Number of seams added = 163
# Number of seams added = 164
# Number of seams added = 165
# Number of seams added = 166
# Number of seams added = 167
# Number of seams added = 168
# Number of seams added = 169
# Number of seams added = 170
# Number of seams added = 171
# Number of seams added = 172
# Number of seams added = 173
# Number of seams added = 174
# Number of seams added = 175
# Number of seams added = 176
# Number of seams added = 177
# Number of seams added = 178
# Number of seams added = 179
# Number of seams added = 180
# Number of seams added = 181
# Number of seams added = 182
# Number of seams added = 183
# Number of seams added = 184
# Number of seams added = 185
# Number of seams added = 186
# Number of seams added = 187
# Number of seams added = 188
# Number of seams added = 189
# Number of seams added = 190
# Number of seams added = 191
# Number of seams added = 192
# Number of seams added = 193
# Number of seams added = 194
# Number of seams added = 195
# Number of seams added = 196
# Number of seams added = 197
# Number of seams added = 198
# Number of seams added = 199
# Number of seams added = 200
# Number of seams added = 201
